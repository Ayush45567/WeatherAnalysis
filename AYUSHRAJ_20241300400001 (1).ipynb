# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/weather_data.csv")

# %%
# Display basic information about the dataset
print("Dataset Overview:\n", df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           730 non-null    object
#  1   Temperature_C  730 non-null    float64
#  2   Rainfall_mm    730 non-null    float64
#  3   Season         730 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 22.9+ KB
# Dataset Overview:
#  None

# %%
# Display first few rows
print("\nFirst 5 Rows of the Dataset:")
print(df.head())
# Out:
# First 5 Rows of the Dataset:
#          Date  Temperature_C  Rainfall_mm  Season
# 0  2022-01-01      24.967142     0.092809  Winter
# 1  2022-01-02      18.617357     0.000000  Winter
# 2  2022-01-03      26.476885     0.626405  Winter
# 3  2022-01-04      35.230299     0.000000  Winter
# 4  2022-01-05      17.658466     0.000000  Winter

# %%
# Check for missing values
print("\nMissing Values:\n", df.isnull().sum())
# Out:
# Missing Values:
#  Date             0
# Temperature_C    0
# Rainfall_mm      0
# Season           0
# dtype: int64

# %%
# Display basic statistics
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#        Temperature_C  Rainfall_mm
# count     730.000000   730.000000
# mean       19.859661     1.636320
# std         9.840121     3.771265
# min       -12.412673     0.000000
# 25%        13.019785     0.000000
# 50%        19.898903     0.000000
# 75%        26.276760     0.908591
# max        58.527315    37.208615

# %%
# Set seaborn style for better visuals
sns.set_style("whitegrid")

# %%
# Plot temperature trends over time
plt.figure(figsize=(12, 5))
plt.plot(df["Date"], df["Temperature_C"], color="tab:red", alpha=0.7)
plt.title("Daily Temperature Trend", fontsize=14)
plt.xlabel("Date")
plt.ylabel("Temperature (°C)")
plt.xticks(rotation=45)
plt.show()

# %%
# Boxplot of temperature distribution by season
plt.figure(figsize=(8, 5))
sns.boxplot(x="Season", y="Temperature_C", data=df, palette="coolwarm")
plt.title("Temperature Distribution by Season")
plt.xlabel("Season")
plt.ylabel("Temperature (°C)")
plt.show()
# Out:
# <ipython-input-44-52639f4859db>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Season", y="Temperature_C", data=df, palette="coolwarm")

# %%
# Histogram of rainfall distribution
plt.figure(figsize=(8, 5))
sns.histplot(df["Rainfall_mm"], bins=30, kde=True, color="blue")
plt.title("Rainfall Distribution")
plt.xlabel("Rainfall (mm)")
plt.ylabel("Frequency")
plt.show()

# %%
# Average temperature by season
plt.figure(figsize=(8, 5))
season_avg_temp = df.groupby("Season")["Temperature_C"].mean().reindex(["Winter", "Spring", "Summer", "Autumn"])
season_avg_temp.plot(kind="bar", color=["blue", "green", "red", "orange"])
plt.title("Average Temperature by Season")
plt.xlabel("Season")
plt.ylabel("Average Temperature (°C)")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.title("Average Monthly Rainfall Trend")
plt.xlabel("Month")
plt.ylabel("Average Rainfall (mm)")
plt.xticks(range(1, 13))
plt.show()
